# %% [markdown]
# # Пример анализа данных
# ## Open Policing Project
# ### Датасет содержит информацию об остановках автомобилей полицией

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# загрузить данные в DataFrame
poldf = pd.read_csv('police.csv')
poldf
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# 0            20.0       White                        Speeding
# 1            40.0       White                        Speeding
# 2            33.0       White                        Speeding
# 3            19.0       White                Call for Service
# 4            21.0       White                        Speeding
# ...           ...         ...                             ...
# 91736        29.0       White                        Speeding
# 91737        33.0       White  Equipment/Inspection Violation
# 91738        23.0       White         Other Traffic Violation
# 91739        22.0       White                        Speeding
# 91740        56.0    Hispanic                        Speeding
#
#               violation  search_conducted search_type   stop_outcome  \
# 0              Speeding             False         NaN       Citation
# 1              Speeding             False         NaN       Citation
# 2              Speeding             False         NaN       Citation
# 3                 Other             False         NaN  Arrest Driver
# 4              Speeding             False         NaN       Citation
# ...                 ...               ...         ...            ...
# 91736          Speeding             False         NaN        Warning
# 91737         Equipment             False         NaN        Warning
# 91738  Moving violation             False         NaN        Warning
# 91739          Speeding             False         NaN       Citation
# 91740          Speeding             False         NaN       Citation
#
#       is_arrested stop_duration  drugs_related_stop
# 0           False      0-15 Min               False
# 1           False      0-15 Min               False
# 2           False      0-15 Min               False
# 3            True     16-30 Min               False
# 4           False      0-15 Min               False
# ...           ...           ...                 ...
# 91736       False      0-15 Min               False
# 91737       False      0-15 Min               False
# 91738       False      0-15 Min               False
# 91739       False      0-15 Min               False
# 91740       False      0-15 Min               False
#
# [91741 rows x 15 columns]

# %%
# проверить размеры датафрейма
len(poldf)
# Out:
# 91741

# %%
# проверить типы данных в датафрейме
poldf.dtypes
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
# проверить количество отсутствующих данных
poldf.isna().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %% [markdown]
# ### 1. Удалить столбец, в котром отсутствуют данные
#
# - Методы drop, dropna
# - Обратить внимание на аргументы по-умолчанию
# - Проверить результат

# %%
poldf.dropna(axis = 0, how = 'any', thresh=None ,subset = None, inplace = True)

# %%
poldf = poldf.drop(columns = 'county_name')

# %%
poldf.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# county_name           0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# dtype: int64

# %% [markdown]
# ### 2. Кто чаще нарушает скоростной режим - женщины или мужчины?
#
# - Столбцы: driver_gender, violation
# - Разные способы ответить на вопрос

# %%
man=poldf[poldf['driver_gender'] == 'M']
len(man)
# Out:
# 62895

# %%
woman=poldf[poldf['driver_gender'] == 'F']
len(woman)
# Out:
# 23511

# %%
if len(man) > len(woman):
    print('Мужчины нарушают чаще')
elif len(woman) > len(man):
    print('Женщины нарушают чаще')
else:
    print('Одинаково нарушают')
# Out:
# Мужчины нарушают чаще

# %% [markdown]
# ### 3. Влияет ли пол водителя на проведение розыска во время остановки?
#
# - Столбцы: driver_gender, search_conducted
# - Трудно определить причинно-следственную связь, но можно выявить отношения
# - Использовать все доступные факторы для выявления отношений

# %%
man=poldf[(poldf['driver_gender'] == 'M')&(poldf['search_conducted'] == True)]
len(man)
# Out:
# 2725

# %%
woman=poldf[(poldf['driver_gender'] == 'F')&(poldf['search_conducted'] == True)]
len(woman)
# Out:
# 471

# %%
if len(man) > len(woman):
    print('Мужчины помогают чаще')
elif len(woman) > len(man):
    print('Женщины помогают чаще')
else:
    print('Не важно')
# Out:
# Мужчины помогают чаще

# %% [markdown]
# ### 4. Почему вид розыска (search_type) так часто отсутствует?
#
# - Столбцы: driver_gender, search_conducted
# - pandas во время расчетов по-умолчанию выбрасывает отсутствующие данные (Null, NA, NaN, False)
# - Использовать все доступные факторы для выявления отношений

# %%
typ = poldf['search_type'].isnull().sum()
typ
# Out:
# 88545

# %%
typ2 = poldf[poldf['search_conducted'] == False]
len(typ2)
# Out:
# 88545

# %%
if typ == len(typ2):
    print('Вид розыска отсутствует из-за отсутсвия самого розыска')
else:
    print('Причина неизвестна')
# Out:
# Вид розыска отсутствует из-за отсутсвия самого розыска

# %% [markdown]
# ### 5. Как часто водителя обыскивают (Protective Frisk)?
#
# - Столбцы: search_type
# - строковые методы для поиска частичных совпадений

# %%
pf1 = poldf['search_type']
len(pf1)
# Out:
# 91741

# %%
pf2 = poldf['search_type'].isnull().sum()
pf2
# Out:
# 88545

# %%
pf3 = poldf[poldf['search_type'] == 'Protective Frisk']
len(pf3)
# Out:
# 161

# %%
pf4 = len(pf1) - pf2 #Кол-во розысков
pf4 = len(pf3)/pf4 
print('Шанс обыска: ')
print(pf4)
# Out:
# Шанс обыска:
# 0.050375469336670836

# %% [markdown]
# ### 6. В каком году меньше всего полиция останавливала автомобили?
#
# - Столбцы: stop_date, stop_time
# - тип данных datetime и его методы

# %%
t1 = poldf[(poldf['stop_date'] >= '2005-01-01')& (poldf['stop_date'] < '2006-01-01')]
d1 = '2005'
t2 = poldf[(poldf['stop_date'] >= '2006-01-01')& (poldf['stop_date'] < '2007-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2006'
t2 = poldf[(poldf['stop_date'] >= '2007-01-01')& (poldf['stop_date'] < '2008-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2007'
t2 = poldf[(poldf['stop_date'] >= '2008-01-01')& (poldf['stop_date'] < '2009-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2008'
t2 = poldf[(poldf['stop_date'] >= '2009-01-01')& (poldf['stop_date'] < '2010-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2009'
t2 = poldf[(poldf['stop_date'] >= '2010-01-01')& (poldf['stop_date'] < '2011-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2010'
t2 = poldf[(poldf['stop_date'] >= '2011-01-01')& (poldf['stop_date'] < '2012-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2011'
t2 = poldf[(poldf['stop_date'] >= '2012-01-01')& (poldf['stop_date'] < '2013-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2012'
t2 = poldf[(poldf['stop_date'] >= '2013-01-01')& (poldf['stop_date'] < '2014-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2013'
t2 = poldf[(poldf['stop_date'] >= '2014-01-01')& (poldf['stop_date'] < '2015-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2014'
t2 = poldf[(poldf['stop_date'] >= '2015-01-01')& (poldf['stop_date'] < '2016-01-01')]
if len(t2) < len(t1):
    t1 = t2
    d1 = '2015'

print(d1)
len(t1)
# Out:
# 2005
# 2558

# %% [markdown]
# ### 7. Как изменялось количество остановок, связанных с запрещенными веществами, в течение дня?
#
# - Столбцы: stop_datetime, drug_related_stop
# - groubby
# - plot

# %%
grp = poldf.groupby(['stop_time','drugs_related_stop'])
grp.first()
# Out:
#                                stop_date driver_gender  driver_age_raw  \
# stop_time drugs_related_stop
# 00:00     False               2005-10-02             F          1982.0
#           True                2005-10-01             M          1988.0
# 00:01     False               2006-01-30             M          1963.0
#           True                2007-12-01             M          1991.0
# 00:02     False               2006-01-15             M          1989.0
# ...                                  ...           ...             ...
# 23:57     True                2009-04-15             M          1984.0
# 23:58     False               2006-03-02             M          1986.0
#           True                2007-08-05             M          1987.0
# 23:59     False               2006-01-14             M          1966.0
#           True                2007-09-03             M          1989.0
#
#                               driver_age driver_race  \
# stop_time drugs_related_stop
# 00:00     False                     23.0       White
#           True                      17.0       White
# 00:01     False                     43.0       White
#           True                      16.0       Black
# 00:02     False                     17.0       White
# ...                                  ...         ...
# 23:57     True                      25.0       Black
# 23:58     False                     20.0       White
#           True                      20.0       White
# 23:59     False                     40.0       White
#           True                      18.0    Hispanic
#
#                                                violation_raw  \
# stop_time drugs_related_stop
# 00:00     False                                     Speeding
#           True                Equipment/Inspection Violation
# 00:01     False                                     Speeding
#           True                Equipment/Inspection Violation
# 00:02     False                                     Speeding
# ...                                                      ...
# 23:57     True                Equipment/Inspection Violation
# 23:58     False                                     Speeding
#           True                       Other Traffic Violation
# 23:59     False                                     Speeding
#           True                Equipment/Inspection Violation
#
#                                      violation  search_conducted  \
# stop_time drugs_related_stop
# 00:00     False                       Speeding             False
#           True                       Equipment              True
# 00:01     False                       Speeding             False
#           True                       Equipment              True
# 00:02     False                       Speeding             False
# ...                                        ...               ...
# 23:57     True                       Equipment              True
# 23:58     False                       Speeding             False
#           True                Moving violation              True
# 23:59     False                       Speeding             False
#           True                       Equipment              True
#
#                                                       search_type  \
# stop_time drugs_related_stop
# 00:00     False                              Reasonable Suspicion
#           True                                     Probable Cause
# 00:01     False               Probable Cause,Reasonable Suspicion
#           True                                 Incident to Arrest
# 00:02     False                                Incident to Arrest
# ...                                                           ...
# 23:57     True                                     Probable Cause
# 23:58     False                                               NaN
#           True                                     Probable Cause
# 23:59     False                                    Probable Cause
#           True                                     Probable Cause
#
#                                stop_outcome is_arrested stop_duration
# stop_time drugs_related_stop
# 00:00     False                    Citation       False      0-15 Min
#           True                Arrest Driver        True     16-30 Min
# 00:01     False                    Citation       False     16-30 Min
#           True                     Citation       False       30+ Min
# 00:02     False                    Citation       False      0-15 Min
# ...                                     ...         ...           ...
# 23:57     True                     Citation       False       30+ Min
# 23:58     False                    Citation       False      0-15 Min
#           True                Arrest Driver        True       30+ Min
# 23:59     False                    Citation       False      0-15 Min
#           True                    No Action       False     16-30 Min
#
# [1985 rows x 12 columns]

# %%
zap = poldf[['stop_time','drugs_related_stop']]
plt = zap.plot(x = 'stop_time', y = 'drugs_related_stop')
# не нашёл как перевести drugs_related_stop в float внутри plot
plt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-1c94ee4beb03> in <module>
#       1 zap = poldf[['stop_time','drugs_related_stop']]
# ----> 2 plt = zap.plot(x = 'stop_time', y = 'drugs_related_stop')
#       3 plt
#
# D:\Python\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# D:\Python\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# D:\Python\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     259     def generate(self):
#     260         self._args_adjust()
# --> 261         self._compute_plot_data()
#     262         self._setup_subplots()
#     263         self._make_plot()
#
# D:\Python\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     408         # no non-numeric frames or series allowed
#     409         if is_empty:
# --> 410             raise TypeError("no numeric data to plot")
#     411
#     412         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %% [markdown]
# ### 8. Верно ли, что большинство остановок происходило ночью?
#
# - Столбцы: stop_datetime
# - groubby
# - plot

# %%
nigh = poldf.groupby(['stop_time'])
nigh.first()
# Out:
#             stop_date driver_gender  driver_age_raw  driver_age driver_race  \
# stop_time
# 00:00      2005-10-01             M          1988.0        17.0       White
# 00:01      2006-01-30             M          1963.0        43.0       White
# 00:02      2006-01-15             M          1989.0        17.0       White
# 00:03      2006-07-07             F          1975.0        31.0       White
# 00:04      2006-03-15             M          1984.0        22.0       White
# ...               ...           ...             ...         ...         ...
# 23:55      2005-10-09             M          1985.0        20.0       White
# 23:56      2005-10-21             M          1983.0        22.0       White
# 23:57      2005-11-26             M          1977.0        28.0       White
# 23:58      2006-03-02             M          1986.0        20.0       White
# 23:59      2006-01-14             M          1966.0        40.0       White
#
#                             violation_raw  violation  search_conducted  \
# stop_time
# 00:00      Equipment/Inspection Violation  Equipment              True
# 00:01                            Speeding   Speeding             False
# 00:02                            Speeding   Speeding             False
# 00:03                            Speeding   Speeding             False
# 00:04                            Speeding   Speeding             False
# ...                                   ...        ...               ...
# 23:55                            Speeding   Speeding             False
# 23:56                            Speeding   Speeding             False
# 23:57                            Speeding   Speeding             False
# 23:58                            Speeding   Speeding             False
# 23:59                            Speeding   Speeding             False
#
#                                    search_type   stop_outcome is_arrested  \
# stop_time
# 00:00                           Probable Cause  Arrest Driver        True
# 00:01      Probable Cause,Reasonable Suspicion       Citation       False
# 00:02                       Incident to Arrest       Citation       False
# 00:03        Incident to Arrest,Probable Cause       Citation       False
# 00:04                           Probable Cause       Citation       False
# ...                                        ...            ...         ...
# 23:55                 Inventory,Probable Cause       Citation       False
# 23:56                           Probable Cause       Citation       False
# 23:57                       Incident to Arrest       Citation       False
# 23:58                           Probable Cause       Citation       False
# 23:59                           Probable Cause       Citation       False
#
#           stop_duration  drugs_related_stop
# stop_time
# 00:00         16-30 Min                True
# 00:01         16-30 Min               False
# 00:02          0-15 Min               False
# 00:03          0-15 Min               False
# 00:04          0-15 Min               False
# ...                 ...                 ...
# 23:55          0-15 Min               False
# 23:56          0-15 Min               False
# 23:57          0-15 Min               False
# 23:58          0-15 Min               False
# 23:59          0-15 Min               False
#
# [1436 rows x 13 columns]

# %%
n1 = poldf[(poldf['stop_time'] < '07:00')&(poldf['stop_time'] >= '00:00')]
print(len(n1))
n2 = poldf[(poldf['stop_time'] <= '23:59')&(poldf['stop_time'] >= '07:00')]
print(len(n2))
# Out:
# 17564
# 74177

# %%
n3 = poldf.reset_index().plot(x = 'stop_time', y='index' )

# %% [markdown]
# ### 9. Найти плохие данные в столбце stop_duration (длительность остановки) и исправить их.
#
# - Столбцы: stop_datetime
# - loc

# %%
mm = poldf.loc[(poldf.stop_duration != '0-15 Min') & (poldf.stop_duration != '16-30 Min') & (poldf.stop_duration != '30+ Min')]
mm
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 25     2005-09-03     16:02           NaN             NaN         NaN
# 29     2005-09-26     01:05           NaN             NaN         NaN
# 52     2005-10-01     13:09           NaN             NaN         NaN
# 110    2005-10-03     19:50           NaN             NaN         NaN
# 124    2005-10-04     11:43           NaN             NaN         NaN
# ...           ...       ...           ...             ...         ...
# 91637  2015-12-27     09:41           NaN             NaN         NaN
# 91660  2015-12-28     02:28           NaN             NaN         NaN
# 91674  2015-12-28     12:01           NaN             NaN         NaN
# 91710  2015-12-30     13:27           NaN             NaN         NaN
# 91713  2015-12-30     17:07           NaN             NaN         NaN
#
#       driver_race violation_raw violation  search_conducted search_type  \
# 25            NaN           NaN       NaN             False         NaN
# 29            NaN           NaN       NaN             False         NaN
# 52            NaN           NaN       NaN             False         NaN
# 110           NaN           NaN       NaN             False         NaN
# 124           NaN           NaN       NaN             False         NaN
# ...           ...           ...       ...               ...         ...
# 91637         NaN           NaN       NaN             False         NaN
# 91660         NaN           NaN       NaN             False         NaN
# 91674         NaN           NaN       NaN             False         NaN
# 91710         NaN           NaN       NaN             False         NaN
# 91713         NaN           NaN       NaN             False         NaN
#
#       stop_outcome is_arrested stop_duration  drugs_related_stop
# 25             NaN         NaN           NaN               False
# 29             NaN         NaN           NaN               False
# 52             NaN         NaN           NaN               False
# 110            NaN         NaN           NaN               False
# 124            NaN         NaN           NaN               False
# ...            ...         ...           ...                 ...
# 91637          NaN         NaN           NaN               False
# 91660          NaN         NaN           NaN               False
# 91674          NaN         NaN           NaN               False
# 91710          NaN         NaN           NaN               False
# 91713          NaN         NaN           NaN               False
#
# [5335 rows x 14 columns]

# %%
poldf.loc[(poldf.stop_duration != '0-15 Min') & (poldf.stop_duration != '16-30 Min') & (poldf.stop_duration != '30+ Min')] = '30+ Min'
#исправление

# %%
mm = poldf.loc[(poldf.stop_duration != '0-15 Min') & (poldf.stop_duration != '16-30 Min') & (poldf.stop_duration != '30+ Min')]
mm
# Out:
# Empty DataFrame
# Columns: [stop_date, stop_time, driver_gender, driver_age_raw, driver_age, driver_race, violation_raw, violation, search_conducted, search_type, stop_outcome, is_arrested, stop_duration, drugs_related_stop]
# Index: []

# %% [markdown]
# ### 10. Каково среднее время остановки (stop_duration) для каждого нарушения (violation_raw)?
#
# - Столбцы: stop_duration, violation_raw
# - Преобразование строк в числа
# - Важно не только среднее, но и количество

# %%
sr = poldf.groupby('violation_raw')
sr.first()
# Out:
#                                    stop_date stop_time  county_name  \
# violation_raw
# APB                               2005-10-05     16:10          NaN
# Call for Service                  2005-02-20     17:15          NaN
# Equipment/Inspection Violation    2005-03-23     09:45          NaN
# Motorist Assist/Courtesy          2005-10-12     07:50          NaN
# Other Traffic Violation           2005-08-07     16:50          NaN
# Registration Violation            2005-10-03     23:20          NaN
# Seatbelt Violation                2012-12-01     10:20          NaN
# Special Detail/Directed Patrol    2005-10-04     00:36          NaN
# Speeding                          2005-01-02     01:55          NaN
# Suspicious Person                 2005-10-07     23:30          NaN
# Violation of City/Town Ordinance  2005-10-05     17:00          NaN
# Warrant                           2006-04-26     13:45          NaN
#
#                                  driver_gender  driver_age_raw  driver_age  \
# violation_raw
# APB                                          M          1979.0        26.0
# Call for Service                             M          1986.0        19.0
# Equipment/Inspection Violation               M          1982.0        23.0
# Motorist Assist/Courtesy                     M             0.0        32.0
# Other Traffic Violation                      M          1953.0        52.0
# Registration Violation                       M          1954.0        51.0
# Seatbelt Violation                           M          1970.0        42.0
# Special Detail/Directed Patrol               M          1961.0        44.0
# Speeding                                     M          1985.0        20.0
# Suspicious Person                            M          1986.0        19.0
# Violation of City/Town Ordinance             M          1985.0        20.0
# Warrant                                      M          1978.0        28.0
#
#                                  driver_race            violation  \
# violation_raw
# APB                                    White                Other
# Call for Service                       White                Other
# Equipment/Inspection Violation         Black            Equipment
# Motorist Assist/Courtesy               White                Other
# Other Traffic Violation                White     Moving violation
# Registration Violation                 White  Registration/plates
# Seatbelt Violation                     Black            Seat belt
# Special Detail/Directed Patrol         White                Other
# Speeding                               White             Speeding
# Suspicious Person                      White                Other
# Violation of City/Town Ordinance       White                Other
# Warrant                             Hispanic                Other
#
#                                   search_conducted  \
# violation_raw
# APB                                          False
# Call for Service                             False
# Equipment/Inspection Violation               False
# Motorist Assist/Courtesy                     False
# Other Traffic Violation                      False
# Registration Violation                       False
# Seatbelt Violation                           False
# Special Detail/Directed Patrol               False
# Speeding                                     False
# Suspicious Person                             True
# Violation of City/Town Ordinance             False
# Warrant                                      False
#
#                                                           search_type  \
# violation_raw
# APB                                                Incident to Arrest
# Call for Service                                   Incident to Arrest
# Equipment/Inspection Violation                         Probable Cause
# Motorist Assist/Courtesy                           Incident to Arrest
# Other Traffic Violation           Incident to Arrest,Protective Frisk
# Registration Violation                             Incident to Arrest
# Seatbelt Violation                    Probable Cause,Protective Frisk
# Special Detail/Directed Patrol                       Protective Frisk
# Speeding                                           Incident to Arrest
# Suspicious Person                                      Probable Cause
# Violation of City/Town Ordinance                   Incident to Arrest
# Warrant                                            Incident to Arrest
#
#                                       stop_outcome  is_arrested stop_duration  \
# violation_raw
# APB                                       Citation        False      0-15 Min
# Call for Service                     Arrest Driver         True     16-30 Min
# Equipment/Inspection Violation            Citation        False      0-15 Min
# Motorist Assist/Courtesy                 No Action        False      0-15 Min
# Other Traffic Violation                   Citation        False      0-15 Min
# Registration Violation                    Citation        False      0-15 Min
# Seatbelt Violation                        Citation        False      0-15 Min
# Special Detail/Directed Patrol       Arrest Driver         True       30+ Min
# Speeding                                  Citation        False      0-15 Min
# Suspicious Person                 Arrest Passenger         True     16-30 Min
# Violation of City/Town Ordinance          Citation        False      0-15 Min
# Warrant                              Arrest Driver         True      0-15 Min
#
#                                   drugs_related_stop
# violation_raw
# APB                                            False
# Call for Service                               False
# Equipment/Inspection Violation                 False
# Motorist Assist/Courtesy                       False
# Other Traffic Violation                        False
# Registration Violation                         False
# Seatbelt Violation                             False
# Special Detail/Directed Patrol                 False
# Speeding                                       False
# Suspicious Person                               True
# Violation of City/Town Ordinance               False
# Warrant                                        False

# %%
v1 = poldf.loc[poldf.violation_raw=='APB']
vr = v1.stop_duration.mode()
print(len(v1))
print(vr)
# Out:
# 79
# 0    0-15 Min
# dtype: object

# %% [markdown]
# ### 11. Визуализировать результаты пункта 10
#
# - Не использовать plot для категориальных данных
# - Сортировка и ориентация графика даст лучший результат

# %% [markdown]
# ### 12. Рассчитать возрастное распределение для каждого нарушения
#
# - Гистограммы (метод hist) - для визуализации распределений

# %%
h = poldf['driver_age'].hist()
fig = h.get_figure()

# %% [markdown]
# ### 13. Представьте, что столбца возраст водителя (driver_age) нет. Создать аналогичный столбец на основе года рождения (driver_age_raw) и назвать его (driver_age_new).
#
# - head и tail могут быть не репрезентативны
# - даже если в столбце данные частично отсутствуют, оставшиеся могут быть не корректными
# - гистограммы - хороший способ проверить корректность выполненных преобразований
